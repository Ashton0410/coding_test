# %%
# solution1
def solution(angle):
    answer = 0
    if 0 < angle < 90:
        answer = 1
    elif angle == 90:
        answer = 2
    elif 90 < angle < 180:
        answer = 3
    elif angle == 180:
        answer = 4
    return answer
# solution1-1
def solution(angle):
    
    answer = []
    if angle <90:
        answer = 1
    elif angle == 90:
        answer = 2
    elif angle == 180:
        answer=4
    else:
        answer = 3
    return answer


# solution2
def solution(angle):
    answer = (angle // 90) * 2 + (angle % 90 > 0) * 1 
    return answer


# solution3
def solution(angle):
    if angle<=90:
        return 1 if angle<90 else 2
    else:
        return 3 if angle<180 else 4
    
# solution4

def solution(angle):
    answer = 0

    if angle > 90:
        answer = int(angle / 90) + 2
    else:
        answer = int(angle / 90) + 1

    return answer
    
# solution5
def solution(angle):
    angles = {180: 4, 91: 3, 90: 2, 0: 1}
    for base, result in angles.items():
        if angle >= base:
            return result
        

# solution6-1
def solution(angle):
    return 2 if angle==90 else 1 if angle<90 else 4 if angle==180 else 3

# solution6-2
def solution(a):
    return 1 if a < 90 else 2 if a == 90 else 3 if a<180 else 4
