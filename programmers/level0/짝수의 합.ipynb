# %%
# solution1
def solution(n):
    answer = 0
    for i in range(n+1):
        if i % 2 ==0:
            answer += i
    return answer

# solution2
def solution(n):
    answer = 0
    for i in range(2, n+1, 2):
        answer += i
    return answer

# solution3
def solution(n):
    return sum([i for i in range(2, n + 1, 2)])

# solution4
def solution(n):
    return 2*(n//2)*((n//2)+1)/2

# solution5
def solution(n):
    return sum(filter(lambda v: v % 2 == 0, [_ for _ in range(n+1)]))
# solution6-1
def solution(n):
    return sum(range(0, n+1, 2))

# solution6-2
def solution(n):
    return sum(i for i in range(0,n+1,2))

# solution7
def solution(n):
    return sum(i for i in range(1,n+1) if i%2==0)

# solution8
def solution(n):
     return sum([i if i%2==0 else 0 for i in range(2,n+1)])

# solution9
def solution(n):
    answer = []
    for i in range(2, n + 1, 2):
        answer.append(i)
    return sum(answer)


# solution10
def solution(n):
    answer = 0
    for i, number in enumerate(range(0, n + 1)):
        if i % 2 == 0:
            answer += i

    return answer

# solution11
def solution(n):
    return (n // 2) * (n // 2 + 1) if n % 2 == 0 else ((n - 1) // 2) * ((n - 1) // 2 + 1)
